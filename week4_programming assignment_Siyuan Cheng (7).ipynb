# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import ipywidgets

# %%
# set column name
ufo_country = pd.read_csv("https://github.com/UIUC-iSchool-DataViz/is445_AOUAOG_fall2021/raw/master/week05/data/ufo-scrubbed-geocoded-time-standardized-00.csv",
                  names = ["date", "city", "state", "country",
                          "shape", "duration_seconds", "duration",
                          "comment", "report_date", "latitude", "longitude"],
                  parse_dates = ["date", "report_date"])

# %%
ufo_country
# Out:
#                      date                  city state country     shape  \
# 0     1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1     1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2     1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3     1956-10-10 21:00:00                  edna    tx      us    circle
# 4     1960-10-10 20:00:00               kaneohe    hi      us     light
# ...                   ...                   ...   ...     ...       ...
# 80327 2013-09-09 21:15:00             nashville    tn      us     light
# 80328 2013-09-09 22:00:00                 boise    id      us    circle
# 80329 2013-09-09 22:00:00                  napa    ca      us     other
# 80330 2013-09-09 22:20:00                vienna    va      us    circle
# 80331 2013-09-09 23:00:00                edmond    ok      us     cigar
#
#        duration_seconds    duration  \
# 0                2700.0  45 minutes
# ...

# %%
# correct NAN
ufo_country = ufo_country.fillna({'country':'unknown', 'state': 'unknown', 'shape':'unknown'})

# %%
ufo_country
# Out:
#                      date                  city    state  country     shape  \
# 0     1949-10-10 20:30:00            san marcos       tx       us  cylinder
# 1     1949-10-10 21:00:00          lackland afb       tx  unknown     light
# 2     1955-10-10 17:00:00  chester (uk/england)  unknown       gb    circle
# 3     1956-10-10 21:00:00                  edna       tx       us    circle
# 4     1960-10-10 20:00:00               kaneohe       hi       us     light
# ...                   ...                   ...      ...      ...       ...
# 80327 2013-09-09 21:15:00             nashville       tn       us     light
# 80328 2013-09-09 22:00:00                 boise       id       us    circle
# 80329 2013-09-09 22:00:00                  napa       ca       us     other
# 80330 2013-09-09 22:20:00                vienna       va       us    circle
# 80331 2013-09-09 23:00:00                edmond       ok       us     cigar
#
#        duration_seconds    duration  \
# ...

# %%
# set sampling
import random

# set a seed
random.seed(1234)
# 5000 samples
nsamples = 5000
small_sample = np.random.choice(range(len(ufo_country)-1), nsamples, replace=False)

# %%
small_sample
# Out:
# array([55906, 56179, 53360, ..., 78845, 78537, 51413])

# %%
ufo_small = ufo_country.loc[small_sample]

# %%
ufo_small
# Out:
#                      date                           city state  country  \
# 55906 1980-07-13 00:00:00                       hardwick    vt       us
# 56179 2013-07-13 23:09:00                         dallas    tx       us
# 53360 2007-06-03 17:00:00                      hempstead    ny       us
# 66424 1996-08-15 02:30:00                   grand rapids    mi       us
# 27083 2007-02-17 03:30:00  pacific/algona (route 167 sb)    wa  unknown
# ...                   ...                            ...   ...      ...
# 26160 2011-02-12 01:55:00                       cape may    nj       us
# 36427 1993-04-13 22:30:00                   indianapolis    in       us
# 78845 1993-09-03 15:00:00                    burnt ranch    ca       us
# 78537 2012-09-29 21:15:00                           erie    pa       us
# 51413 1996-06-24 15:00:00                         smryna    ga  unknown
#
#           shape  duration_seconds       duration  \
# 55906  cylinder              40.0      half hour
# ...

# %%
# count the variable "country"
sightings = ufo_small.groupby(['country'])['city'].describe()
sightings
# Out:
#         count unique                            top freq
# country
# au         31     19  melbourne (vic&#44 australia)    4
# ca        194    120             vancouver (canada)   11
# de          5      5                neuss (germany)    1
# gb        110     80            london (uk/england)    8
# unknown   645    604                     uk/england    7
# us       4015   2265                        phoenix   34

# %%
# sort the data 
ufo_count = sightings["count"]
ufo_order = ufo_count.sort_values()
ufo_order
# Out:
# country
# de            5
# au           31
# gb          110
# ca          194
# unknown     645
# us         4015
# Name: count, dtype: object

# %%
@ipywidgets.interact(style = plt.style.available)
def make_plot(style):
    with plt.style.context(style):
        ax = ufo_order.plot(kind = "bar", rot=90, label='')
        ax.set_xlabel("countries")
        ax.set_ylabel("number of UFO sightings")
    plt.show()
# Out:
# interactive(children=(Dropdown(description='style', options=('Solarize_Light2', '_classic_test_patch', 'bmh', …

# %% [markdown]
# # Explanation

# %% [markdown]
# I would like choose bar chart here. The reason is I think only bar chart can clearly expresses the difference. If I change to
# line chart and scatter plot, the graph will make audience feel confuse and unclear.
